# %% [markdown]
# #### resnet18
#
#     Обучение с LeakyRelu
#
#     Tensorflow:
#
#     mAP=0.2436, IoU: 0.50
#     mAP=0.2436, IoU: 0.55
#     mAP=0.2308, IoU: 0.60
#     mAP=0.2051, IoU: 0.65
#     mAP=0.1923, IoU: 0.70
#     mAP=0.1923, IoU: 0.75
#     mAP=0.0769, IoU: 0.80
#     mAP=0.0000, IoU: 0.85
#     mAP=0.0000, IoU: 0.90
#
#
#     TensorRT:
#
#     Arch: x86_64
#     trtexec command list: ['/home/alexander/TensorRT-7.2.3.4/bin/trtexec', '--onnx=nhwc_maskrcnn_resnet18_512_512_3_trt_mod.onnx', '--saveEngine=nhwc_maskrcnn_resnet18_512_512_3_trt_mod_fp32.engine', '--workspace=2048', '--explicitBatch', '--verbose', '--tacticSources=-cublasLt,+cublas']
#     ]
#     [09/11/2021-02:08:28] [I] Engine built in 100.089 sec.
#     [09/11/2021-02:08:28] [V] [TRT] Allocated persistent device memory of size 253880320
#     [09/11/2021-02:08:28] [V] [TRT] Allocated activation device memory of size 329337856
#     [09/11/2021-02:08:28] [V] [TRT] Assigning persistent memory blocks for various profiles
#     [09/11/2021-02:08:28] [I] Starting inference
#     [09/11/2021-02:08:31] [I] Warmup completed 0 queries over 200 ms
#     [09/11/2021-02:08:31] [I] Timing trace has 0 queries over 3.1437 s
#     [09/11/2021-02:08:31] [I] Trace averages of 10 runs:
#     [09/11/2021-02:08:31] [I] Average on 10 runs - GPU latency: 52.1274 ms - Host latency: 52.635 ms (end to end 103.863 ms, enqueue 3.12729 ms)
#     [09/11/2021-02:08:31] [I] Average on 10 runs - GPU latency: 52.9247 ms - Host latency: 53.3487 ms (end to end 105.47 ms, enqueue 3.03426 ms)
#     [09/11/2021-02:08:31] [I] Average on 10 runs - GPU latency: 52.3353 ms - Host latency: 52.7708 ms (end to end 104.362 ms, enqueue 2.99686 ms)
#     [09/11/2021-02:08:31] [I] Average on 10 runs - GPU latency: 52.2139 ms - Host latency: 52.6348 ms (end to end 104.139 ms, enqueue 3.0108 ms)
#     [09/11/2021-02:08:31] [I] Average on 10 runs - GPU latency: 52.3047 ms - Host latency: 52.7182 ms (end to end 104.305 ms, enqueue 2.63328 ms)
#     [09/11/2021-02:08:31] [I] Host Latency
#     [09/11/2021-02:08:31] [I] min: 51.0955 ms (end to end 102.616 ms)
#     [09/11/2021-02:08:31] [I] max: 58.3729 ms (end to end 113.417 ms)
#     [09/11/2021-02:08:31] [I] mean: 52.8331 ms (end to end 104.431 ms)
#     [09/11/2021-02:08:31] [I] median: 52.8591 ms (end to end 104.16 ms)
#     [09/11/2021-02:08:31] [I] percentile: 58.3729 ms at 99% (end to end 113.417 ms at 99%)
#     [09/11/2021-02:08:31] [I] throughput: 0 qps
#     [09/11/2021-02:08:31] [I] walltime: 3.1437 s
#     [09/11/2021-02:08:31] [I] Enqueue Time
#     [09/11/2021-02:08:31] [I] min: 0.967285 ms
#     [09/11/2021-02:08:31] [I] max: 3.46103 ms
#     [09/11/2021-02:08:31] [I] median: 3.22351 ms
#     [09/11/2021-02:08:31] [I] GPU Compute
#     [09/11/2021-02:08:31] [I] min: 50.6757 ms
#     [09/11/2021-02:08:31] [I] max: 57.939 ms
#     [09/11/2021-02:08:31] [I] mean: 52.3952 ms
#     [09/11/2021-02:08:31] [I] median: 52.4556 ms
#     [09/11/2021-02:08:31] [I] percentile: 57.939 ms at 99%
#     [09/11/2021-02:08:31] [I] total compute time: 3.09132 s
#     &&&& PASSED TensorRT.trtexec # /home/alexander/TensorRT-7.2.3.4/bin/trtexec --onnx=nhwc_maskrcnn_resnet18_512_512_3_trt_mod.onnx --saveEngine=nhwc_maskrcnn_resnet18_512_512_3_trt_mod_fp32.engine --workspace=2048 --explicitBatch --verbose --tacticSources=-cublasLt,+cublas
#
#     CPU times: user 4.39 s, sys: 2.02 s, total: 6.41 s
#     Wall time: 1min 43s
#
#
#
#     Num of detected layers:  235
#     Detected inputs:  1
#     Detected outputs:  2
#     CPU times: user 59.5 s, sys: 7.49 s, total: 1min 6s
#     Wall time: 1min 44s
#
#
#
#     fp32:
#
#     mAP=0.0128, IoU: 0.50
#     mAP=0.0128, IoU: 0.55
#     mAP=0.0000, IoU: 0.60
#     ...
#
#     fp16:
#
#     mAP=0.0128, IoU: 0.50
#     mAP=0.0128, IoU: 0.50
#     mAP=0.0000, IoU: 0.60
#     ...

# %% [markdown]
# #### resnet34
#
# Tensorflow:
#
#   + resnet leaky relu:
#
#           mAP=0.1850, IoU: 0.50
#           mAP=0.1850, IoU: 0.55
#           mAP=0.1795, IoU: 0.60
#           mAP=0.1538, IoU: 0.65
#           mAP=0.1538, IoU: 0.70
#           mAP=0.1538, IoU: 0.75
#           mAP=0.1538, IoU: 0.80
#           mAP=0.0769, IoU: 0.85
#           mAP=0.0000, IoU: 0.90
#           mAP=0.0000, IoU: 0.95
#
#
# TensorRT:
#
#     Arch: x86_64
#     trtexec command list: ['/home/alexander/TensorRT-7.2.3.4/bin/trtexec', '--onnx=nhwc_maskrcnn_resnet34_512_512_3_trt_mod.onnx', '--saveEngine=nhwc_maskrcnn_resnet34_512_512_3_trt_mod_fp32.engine', '--workspace=2048', '--explicitBatch', '--verbose', '--tacticSources=-cublasLt,+cublas']
#     1/2021-01:35:17] [I] Engine built in 96.5468 sec.
#     [09/11/2021-01:35:17] [V] [TRT] Allocated persistent device memory of size 353011200
#     [09/11/2021-01:35:17] [V] [TRT] Allocated activation device memory of size 329411584
#     [09/11/2021-01:35:17] [V] [TRT] Assigning persistent memory blocks for various profiles
#     [09/11/2021-01:35:17] [I] Starting inference
#     [09/11/2021-01:35:21] [I] Warmup completed 0 queries over 200 ms
#     [09/11/2021-01:35:21] [I] Timing trace has 0 queries over 3.17977 s
#     [09/11/2021-01:35:21] [I] Trace averages of 10 runs:
#     [09/11/2021-01:35:21] [I] Average on 10 runs - GPU latency: 56.6492 ms - Host latency: 57.0795 ms (end to end 112.941 ms, enqueue 3.20851 ms)
#     [09/11/2021-01:35:21] [I] Average on 10 runs - GPU latency: 57.141 ms - Host latency: 57.5786 ms (end to end 114.054 ms, enqueue 3.14204 ms)
#     [09/11/2021-01:35:21] [I] Average on 10 runs - GPU latency: 56.7565 ms - Host latency: 57.1871 ms (end to end 113.167 ms, enqueue 3.47255 ms)
#     [09/11/2021-01:35:21] [I] Average on 10 runs - GPU latency: 56.6775 ms - Host latency: 57.1126 ms (end to end 112.908 ms, enqueue 3.33958 ms)
#     [09/11/2021-01:35:21] [I] Average on 10 runs - GPU latency: 56.7412 ms - Host latency: 57.1745 ms (end to end 113.124 ms, enqueue 3.10422 ms)
#     [09/11/2021-01:35:21] [I] Host Latency
#     [09/11/2021-01:35:21] [I] min: 55.7039 ms (end to end 110.883 ms)
#     [09/11/2021-01:35:21] [I] max: 61.2278 ms (end to end 118.215 ms)
#     [09/11/2021-01:35:21] [I] mean: 57.2085 ms (end to end 113.202 ms)
#     [09/11/2021-01:35:21] [I] median: 57.2283 ms (end to end 113.154 ms)
#     [09/11/2021-01:35:21] [I] percentile: 61.2278 ms at 99% (end to end 118.215 ms at 99%)
#     [09/11/2021-01:35:21] [I] throughput: 0 qps
#     [09/11/2021-01:35:21] [I] walltime: 3.17977 s
#     [09/11/2021-01:35:21] [I] Enqueue Time
#     [09/11/2021-01:35:21] [I] min: 0.976074 ms
#     [09/11/2021-01:35:21] [I] max: 4.04333 ms
#     [09/11/2021-01:35:21] [I] median: 3.35693 ms
#     [09/11/2021-01:35:21] [I] GPU Compute
#     [09/11/2021-01:35:21] [I] min: 55.2742 ms
#     [09/11/2021-01:35:21] [I] max: 60.7858 ms
#     [09/11/2021-01:35:21] [I] mean: 56.7751 ms
#     [09/11/2021-01:35:21] [I] median: 56.7932 ms
#     [09/11/2021-01:35:21] [I] percentile: 60.7858 ms at 99%
#     [09/11/2021-01:35:21] [I] total compute time: 3.12263 s
#     &&&& PASSED TensorRT.trtexec # /home/alexander/TensorRT-7.2.3.4/bin/trtexec --onnx=nhwc_maskrcnn_resnet34_512_512_3_trt_mod.onnx --saveEngine=nhwc_maskrcnn_resnet34_512_512_3_trt_mod_fp32.engine --workspace=2048 --explicitBatch --verbose --tacticSources=-cublasLt,+cublas
#
#     CPU times: user 4.15 s, sys: 2.06 s, total: 6.22 s
#     Wall time: 1min 40s
#
#
#
#     Num of detected layers:  283
#     Detected inputs:  1
#     Detected outputs:  2
#     CPU times: user 47.9 s, sys: 6.86 s, total: 54.8 s
#     Wall time: 1min 38s
